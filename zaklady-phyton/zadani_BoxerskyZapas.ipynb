# %% [markdown]
# # Poznámky
# Aby souboj byl zajímavější vytvořte oba boxery s náhodnými hodnotami v rozmezí 1-10 či se stejnými parametry.
#
# > Aby souboj byl zajímavější vytvořte oba boxery se stejnými parametry či s náhodnými hodnotami v rozmezí: x + (1-10)
#
# >Výběr úderu by měl být zcela náhodný.
#
# >Pokaždé se vám vypíše, kdo akci provedl, jaký typ akce dělá a zda se tomu soupeř vyhnul, vykryl a nebo kolik ztratil výdrže.
#
# >Na konci vypište, který boxer vyhrál
#
# > kód zjednodušíte i pokud vytvoříte jen metody Hák a Jab bez výběru strany

# %% [markdown]
# Vytvořte třídu Boxer, která bude obsahovat tyto atributy:
#
# 1.   jméno:str
# 2.   síla:int
# 3.   výdrž:int
# 4.   obratnost:int
# 5.   obrana:int
#
# Vytvořte metody, které budou moc získávat všechny atributy. Měnit budete smět pouze výdrž. Také vytvořte metodu, která vám vypíše vše o této osobě.
#
# Třída boxer bude umět tyto metody:
#
# 1.   pravyHak(enemy)
# 2.   levyHak(enemy)
# 3.   pravyJab(enemy)
# 4.   levyJab(enemy)
#
# Pravý a levý hák snižuje výdrž o:
# > (síla boxera * 1.5) - obrana enemy
#
# Pravý a levý jab snižuje výdrž o:
# > síla boxera - obrana enemy
#
# Pokud bude obrana větší než síla, ztratí boxer alespoň 1 život.
#
# Boxer má možnost útoku se zcela vyhnout bez ohledu na kontrolu krytu. Tato šance odpovídá hodnotě obratnosti/100.
# Zároveň pokud boxer útoku neuhne, má 25% šanci na to, že ránu vykryje.

# %%
import random as rand
class Boxer:
    #TODO

# %%
# Zde vytvořte dva boxery, kteří mezi sebou budou bojovat tak dlouho,
#   dokud jednomu výdrž neklesne na 0

# %% [markdown]
# # Ukázka výstupu:
#
# ```
# Boxer: Muhamad Ali
#         Výdrž: 34
#         Síla: 11
#         Obratnost: 9
#         Obrana: 6
#
# Boxer: Joe Frazer
#         Výdrž: 35
#         Síla: 8
#         Obratnost: 11
#         Obrana: 9
#
# Joe Frazer zasadil levý jab. Muhamad Ali má: 32
# Muhamad Ali zasadil levý jab. Joe Frazer má: 33
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 31
# Joe Frazer zasadil levý hák. Muhamad Ali má: 26.0
# Muhamad Ali vykryl levý hák
# Joe Frazer vykryl pravý jab
# Joe Frazer se vyhnul levému jabu.
# Muhamad Ali vykryl levý hák
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 29
# Muhamad Ali vykryl levý jab
# Joe Frazer vykryl pravý hák
# Joe Frazer se vyhnul levému jabu.
# Muhamad Ali vykryl levý hák
# Joe Frazer zasadil levý hák. Muhamad Ali má: 20.0
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 21.5
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 14.0
# Joe Frazer zasadil pravý hák. Muhamad Ali má: 14.0
# Joe Frazer zasadil levý hák. Muhamad Ali má: 8.0
# Joe Frazer zasadil levý jab. Muhamad Ali má: 6.0
# Joe Frazer vykryl pravý hák
# Joe Frazer vykryl levý jab
# Muhamad Ali vykryl pravý jab
# Joe Frazer se vyhnul pravému jabu.
# Joe Frazer zasadil pravý hák. Muhamad Ali má: 0.0
# Vítězí boxer Joe Frazer
# ```

# %% [markdown]
# # Bonus
# Vytvořte třídu Kolo(), která bude mít tyto atributy
# 1. boxer1:Boxer
# 2. boxer2:Boxer
# 3. početAkcí:int
# 4. početÚderů1:int
# 5. početÚderů2:int
# 6. čísloKola:int
#
# Vytvořte metody, které budou moc získávat všechny atributy. Vytvořte metody pro změnu počtu úderů. Také vytvořte metodu str, která vám vypíše jména, životy a počet úderů, které každý z boxerů zasadil.

# %%
class Kolo:

# %% [markdown]
# Níže vytvořte dva boxery, kteří mezi sebou budou bojovat tak dlouho, dokud jednomu výdrž neklesne na 0 nebo neproběhne 6 kol. Každé kolo bude mít tolik úderů, kolik je na toto kolo vygenerováno akcí. Pokud se do 6 kol nerozhodne o výsledku vyhraje hráč, který zasadil více ran.

# %%
#Zde pište kód pro souboj na kola, kde i vypíšete jaké kolo právě je

# %% [markdown]
# #Ukázka výstupu s koncem před uplynutím 6 kol
# ```
# Boxer: Muhamad Ali
#         Výdrž: 26
#         Síla: 15
#         Obratnost: 13
#         Obrana: 14
#
# Boxer: Joe Frazer
#         Výdrž: 31
#         Síla: 10
#         Obratnost: 9
#         Obrana: 10
#
#
# 1. kolo
#         Muhamad Ali     Joe Frazer
# Životů      26              31
# Úderů        0               0
#
# Joe Frazer se vyhnul levému jabu.
# Muhamad Ali se vyhnul pravému háku.
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 26
#
# 2. kolo
#         Muhamad Ali     Joe Frazer
# Životů      26              26
# Úderů        1               1
#
# Joe Frazer zasadil levý hák. Muhamad Ali má: 25
#
# 3. kolo
#         Muhamad Ali     Joe Frazer
# Životů      25              26
# Úderů        1               2
#
# Muhamad Ali vykryl levý hák
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 13.5
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 1.0
#
# 4. kolo
#         Muhamad Ali     Joe Frazer
# Životů      25              1.0
# Úderů        3               3
#
# Joe Frazer zasadil levý hák. Muhamad Ali má: 24
# Joe Frazer zasadil pravý jab. Muhamad Ali má: 23
# Muhamad Ali zasadil levý jab. Joe Frazer má: 0
#
# __________________________________________
# Závěrečné staty
# __________________________________________
#
# 5. kolo
#         Muhamad Ali     Joe Frazer
# Životů      23              0
# Úderů        4               5
#
# Vítězí boxer Muhamad Ali style KO
# ```

# %% [markdown]
# # ukázka s výstupem po uplynutí 6 kol
#
#
# ```
# Boxer: Muhamad Ali
#         Výdrž: 255
#         Síla: 10
#         Obratnost: 6
#         Obrana: 9
#
# Boxer: Joe Frazer
#         Výdrž: 259
#         Síla: 8
#         Obratnost: 13
#         Obrana: 14
#
#
# 1. kolo
#         Muhamad Ali     Joe Frazer
# Životů      255              259
# Úderů        0               0
#
# Muhamad Ali zasadil levý jab. Joe Frazer má: 258
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 257
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 256
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 255
# Joe Frazer zasadil pravý hák. Muhamad Ali má: 254
#
# 2. kolo
#         Muhamad Ali     Joe Frazer
# Životů      254              255
# Úderů        4               1
#
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 254
# Joe Frazer zasadil pravý jab. Muhamad Ali má: 253
# Joe Frazer zasadil pravý hák. Muhamad Ali má: 252
#
# 3. kolo
#         Muhamad Ali     Joe Frazer
# Životů      252              254
# Úderů        5               3
#
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 253
# Muhamad Ali vykryl pravý jab
# Joe Frazer zasadil pravý hák. Muhamad Ali má: 251
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 252
# Muhamad Ali zasadil levý jab. Joe Frazer má: 251
#
# 4. kolo
#         Muhamad Ali     Joe Frazer
# Životů      251              251
# Úderů        8               5
#
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 250
# Joe Frazer zasadil levý hák. Muhamad Ali má: 250
# Muhamad Ali vykryl levý hák
#
# 5. kolo
#         Muhamad Ali     Joe Frazer
# Životů      250              250
# Úderů        9               7
#
# Joe Frazer vykryl pravý hák
# Muhamad Ali vykryl pravý hák
# Joe Frazer vykryl pravý hák
# Muhamad Ali zasadil pravý jab. Joe Frazer má: 249
#
# 6. kolo
#         Muhamad Ali     Joe Frazer
# Životů      250              249
# Úderů        12               8
#
# Muhamad Ali zasadil pravý hák. Joe Frazer má: 248
#
# __________________________________________
# Závěrečné staty
# __________________________________________
#
# 7. kolo
#         Muhamad Ali     Joe Frazer
# Životů      250              248
# Úderů        13               8
#
# Vítězí boxer Muhamad Ali s 13 body
# ```
